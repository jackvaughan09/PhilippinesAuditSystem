# %%
import requests
import pandas as pd

# %%
url = 'https://app.nanonets.com/api/v2/OCR/Model/17ade9f0-3274-43f3-8e7b-769baa712e0d/LabelFile/?async=false'

data = {'file': open('test.png', 'rb')}

response = requests.post(url, auth=requests.auth.HTTPBasicAuth('ce2b4c7b-ded8-11ed-aa95-128f4318595e', ''), files=data)

print(response.text)
# Out:
# {"message":"Success","result":[{"message":"Success","input":"test.png","prediction":[{"id":"b0a1df03-0e2d-47f8-85e2-c537a1d6c422","label":"table","xmin":96,"ymin":141,"xmax":2068,"ymax":1548,"score":1,"ocr_text":"table","type":"table","cells":[{"id":"b52e84d9-ec7b-4db6-8f0e-9a38e7092f1f","row":1,"col":1,"row_span":1,"col_span":1,"label":"","xmin":96,"ymin":141,"xmax":587,"ymax":763,"score":0.8330078,"text":"10. Real Property Tax ( RPT ) and\nSpecial Education Tax ( SET )\nReceivables were set up at\nthe beginning of the year on\nthe basis of income estimates\nwhich is not in consonance\nwith Section 20 , Volume I of\nthe Manual on New\nAccounting\nSystem ( NGAS ) for Local\nGovernment Units , thus\nrendering the reliability of\nthe account doubtful\nGovernment","row_label":"","verification_status":"correctly_predicted","status":"","failed_validation":"","label_id":""},{"id":"0aa1f627-d4ba-42f4-8a43-c7e214adb5a8","row":1,"col":2,"row_span":1,"col_span":1,"label":"","xmin":587,"ymin":1
# ...

# %%
response.json().keys()
# Out:
# dict_keys(['message', 'result', 'signed_urls'])

# %%
response.json()['result'][0]['prediction'][0]['cells']
# Out:
# [{'id': '35b4afde-e967-4094-9782-a45f31a7c05f',
#   'row': 1,
#   'col': 1,
#   'row_span': 1,
#   'col_span': 1,
#   'label': '',
#   'xmin': 96,
#   'ymin': 141,
#   'xmax': 587,
#   'ymax': 763,
#   'score': 0.8330078,
#   'text': '10. Real Property Tax ( RPT ) and\nSpecial Education Tax ( SET )\nReceivables were set up at\nthe beginning of the year on\nthe basis of income estimates\nwhich is not in consonance\nwith Section 20 , Volume I of\nthe Manual on New\nAccounting\nSystem ( NGAS ) for Local\nGovernment Units , thus\nrendering the reliability of\nthe account doubtful\nGovernment',
#   'row_label': '',
#   'verification_status': 'correctly_predicted',
#   'status': '',
#   'failed_validation': '',
#   'label_id': ''},
#  {'id': 'fbb3c0bf-6881-4159-acb6-232e0bb75d8e',
#   'row': 1,
#   'col': 2,
#   'row_span': 1,
#   'col_span': 1,
#   'label': '',
#   'xmin': 587,
#   'ymin': 141,
#   'xmax': 1058,
#   'ymax': 763,
#   'score': 0.7993164,
# ...

# %%
data = pd.DataFrame(response.json()['message'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data = pd.DataFrame(response.json()['message'])
#
# File ~/Documents/DS/PhilippinesAuditSystem/.venv/lib/python3.8/site-packages/pandas/core/frame.py:781, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     778 # For data is scalar
#     779 else:
#     780     if index is None or columns is None:
# --> 781         raise ValueError("DataFrame constructor not properly called!")
#     783     index = ensure_index(index)
#     784     columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!
